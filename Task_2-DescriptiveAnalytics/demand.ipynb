# %%
import numpy as np
import pandas as pd
from datetime import date, time, datetime, timedelta 
from dateutil import parser
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import random
import timeit

import warnings
warnings.filterwarnings("ignore")

# %%
mydateparser = lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S")
testboston=pd.read_csv("Boston/boston_2015.csv", parse_dates=['start_time', "end_time"], date_parser=mydateparser)

# %%
testboston = testboston.drop(testboston.index[21566])
testboston
# Out:
#                  start_time            end_time  start_station_id  \
# 0       2015-01-01 00:21:44 2015-01-01 00:30:47               115
# 1       2015-01-01 00:27:03 2015-01-01 00:34:21                80
# 2       2015-01-01 00:31:31 2015-01-01 00:35:46                91
# 3       2015-01-01 00:53:46 2015-01-01 01:00:58               115
# 4       2015-01-01 01:07:06 2015-01-01 01:19:21               105
# ...                     ...                 ...               ...
# 1122553 2015-12-31 23:35:04 2015-12-31 23:43:15                73
# 1122554 2015-12-31 23:37:29 2015-12-31 23:47:36               135
# 1122555 2015-12-31 23:38:16 2015-12-31 23:47:26               135
# 1122556 2015-12-31 23:46:04 2015-12-31 23:48:04                36
# 1122557 2015-12-31 23:58:18 2016-01-01 00:12:54               105
#
#         end_station_id                                start_station_name  \
# 0                   96                             Porter Square Station
# 1                   95           MIT Stata Center at Vassar St / Main St
# 2                   68  One Kendall Square at Hampshire St / Portland St
# 3                   96                             Porter Square Station
# 4                   88   Lower Cambridgeport at Magazine St/Riverside Rd
# ...                ...                                               ...
# 1122553             88           Harvard Square at Brattle St / Eliot St
# 1122554             43                                  ID Building East
# 1122555             43                                  ID Building East
# 1122556             36          Boston Public Library - 700 Boylston St.
# 1122557              6   Lower Cambridgeport at Magazine St/Riverside Rd
#
#                                           end_station_name  bike_id  \
# 0        Cambridge Main Library at Broadway / Trowbridg...      277
# 1              Cambridge St - at Columbia St / Webster Ave      648
# 2                    Central Square at Mass Ave / Essex St      555
# 3        Cambridge Main Library at Broadway / Trowbridg...     1307
# 4            Inman Square at Vellucci Plaza / Hampshire St      177
# ...                                                    ...      ...
# 1122553      Inman Square at Vellucci Plaza / Hampshire St     1473
# 1122554                         Rowes Wharf - Atlantic Ave      649
# 1122555                         Rowes Wharf - Atlantic Ave     1552
# 1122556           Boston Public Library - 700 Boylston St.     1083
# 1122557                           Cambridge St. at Joy St.     1305
#
#           user_type
# 0        Subscriber
# 1        Subscriber
# 2        Subscriber
# 3        Subscriber
# 4          Customer
# ...             ...
# 1122553  Subscriber
# 1122554  Subscriber
# 1122555  Subscriber
# 1122556    Customer
# 1122557  Subscriber
#
# [1122557 rows x 8 columns]

# %%
testboston['end_station_id'] = testboston['end_station_id'].astype(int)

# %%
#creating column 'Duration'
testboston["Duration"]=testboston["end_time"]-testboston["start_time"]
x=timedelta(days=5)
x
testboston[testboston["Duration"]>x]
# Out:
#                  start_time            end_time  start_station_id  \
# 17481   2015-03-17 16:26:54 2015-03-24 08:59:15                68
# 18313   2015-03-20 02:24:09 2015-09-27 16:53:58                68
# 19573   2015-03-24 09:24:59 2015-04-01 07:44:53                90
# 22825   2015-03-31 15:50:05 2015-04-08 07:59:44                76
# 34889   2015-04-17 14:24:23 2015-05-02 14:21:18                49
# ...                     ...                 ...               ...
# 1119082 2015-12-25 22:40:48 2015-12-30 22:59:11                33
# 1119642 2015-12-26 20:00:48 2016-01-01 15:32:11                10
# 1119793 2015-12-27 10:46:20 2016-01-03 18:31:17                44
# 1120112 2015-12-27 16:59:30 2016-01-03 21:36:27               108
# 1120221 2015-12-27 21:58:42 2016-03-09 01:21:49                54
#
#          end_station_id                                 start_station_name  \
# 17481                72              Central Square at Mass Ave / Essex St
# 18313                73              Central Square at Mass Ave / Essex St
# 19573                72        Lechmere Station at Cambridge St / First St
# 22825                70  Central Sq Post Office / Cambridge City Hall a...
# 34889               106                          Stuart St. at Charles St.
# ...                 ...                                                ...
# 1119082              21                              Kenmore Sq / Comm Ave
# 1119642             175                      B.U. Central - 725 Comm. Ave.
# 1119793              47              Faneuil Hall - Union St. at North St.
# 1120112              25  Harvard University / SEAS Cruft-Pierce Halls a...
# 1120221             126                               Tremont St / West St
#
#                                         end_station_name  bike_id   user_type  \
# 17481      One Broadway / Kendall Sq at Main St / 3rd St     1079  Subscriber
# 18313            Harvard Square at Brattle St / Eliot St      714    Customer
# 19573      One Broadway / Kendall Sq at Main St / 3rd St      667  Subscriber
# 22825    Harvard Kennedy School at Bennett St / Eliot St      874  Subscriber
# 34889               Mt Pleasant Ave / Dudley Town Common      923  Subscriber
# ...                                                  ...      ...         ...
# 1119082                    Prudential Center / Belvidere      489  Subscriber
# 1119642                                  Brighton Center      498  Subscriber
# 1119793                         Cross St. at Hanover St.      672  Subscriber
# 1120112                         Tremont St / W Newton St      182  Subscriber
# 1120221                  Egleston Square at Columbus Ave      804  Subscriber
#
#                  Duration
# 17481     6 days 16:32:21
# 18313   191 days 14:29:49
# 19573     7 days 22:19:54
# 22825     7 days 16:09:39
# 34889    14 days 23:56:55
# ...                   ...
# 1119082   5 days 00:18:23
# 1119642   5 days 19:31:23
# 1119793   7 days 07:44:57
# 1120112   7 days 04:36:57
# 1120221  72 days 03:23:07
#
# [76 rows x 9 columns]

# %%
def get_weekday (ts):
    return ts.weekday()
#0=Monday 6=Sunday
testboston["Weekday"]=testboston["start_time"].apply(lambda x:get_weekday(x))

# %%
def get_month (ts):
    return ts.month()
#0=Monday 6=Sunday
testboston["Month"]=testboston["start_time"].apply(lambda x:get_month(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-63622cba5460> in <module>
#       2     return ts.month()
#       3 #0=Monday 6=Sunday
# ----> 4 testboston["Month"]=testboston["start_time"].apply(lambda x:get_month(x))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-63622cba5460> in <lambda>(x)
#       2     return ts.month()
#       3 #0=Monday 6=Sunday
# ----> 4 testboston["Month"]=testboston["start_time"].apply(lambda x:get_month(x))
#
# <ipython-input-9-63622cba5460> in get_month(ts)
#       1 def get_month (ts):
# ----> 2     return ts.month()
#       3 #0=Monday 6=Sunday
#       4 testboston["Month"]=testboston["start_time"].apply(lambda x:get_month(x))
#
# TypeError: 'int' object is not callable

# %%
#testboston

# %%
#s=datetime.strptime("2015-01-01","%Y-%m-%d")
#e=datetime.strptime("2015-07-01","%Y-%m-%d")

# %%
#testboston[testboston["start_time"]<e]

# %%
#testboston[testboston["Weekday"]>4]

# %%
testboston["start_time"][21566]

# %%
dicta={}
for i in range(24):
    dicta[i]=0
dicta

# %%
time = pd.Series(dicta)
for x in range(len(testboston)):
    if x==21566:
        x=x+1
    akt=testboston["start_time"][x]
    dicta[akt.hour]=(dicta[akt.hour])+1
print(dicta)

# %%
#improving 
time = pd.Series(dicta)
for x in range(len(testboston)):
    if x==21566:
        x=x+1
    akt=testboston["start_time"][x]
    bkt=testboston["end_time"][x]
    if bkt.hour - s :
        dicta[int(akt.hour) +i]=(dicta[int(akt.hour)])+1
        i += 1
print(dicta)

# %%
p=0
for x in range(len(dicta)):
    p=p+dicta[x]
p

# %%
#testboston["start_time"].dt.year

# %%
plt.bar(range(len(dicta)), list(dicta.values()), align='center')
plt.xticks(range(len(dicta)), list(dicta.keys()))
plt.show()

# %%
dicta_wweek={}
for i in range(24):
    dicta_wweek[i]=0

# %%
testboston["start_time"].dt.weekday 
testboston

# %%
time = pd.Series(dicta)                           
                              
for x in range(len(testboston)):
    if x==21566:
        x=x+1
    akt=testboston["start_time"][x]
    dicta[akt.hour]=(dicta[akt.hour])+1
print(dicta)
